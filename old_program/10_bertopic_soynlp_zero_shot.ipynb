# %%
import pandas as pd
import os
from soynlp.tokenizer import LTokenizer
from soynlp.noun import LRNounExtractor
from soynlp.word import WordExtractor

from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer

from hdbscan import HDBSCAN
from sentence_transformers import SentenceTransformer
from transformers import pipeline
from bertopic.representation import KeyBERTInspired

# %%
IN_DATA_PATH = './data/01_out'
OUT_DATA_PATH = './data/02_out'

in_data_files = []
in_docs = []
total_docs = []

# 폴더내 파일리스트를 가져온다.
input_files = os.listdir(IN_DATA_PATH)

# 입력 파일 로딩 RAW_DATA_PATH에 있는 파일을 DataFrame으로 읽어 드린다.
for in_file in input_files:
    print ("Loading file :%s ..."%in_file)
    df = pd.read_csv(os.path.join(IN_DATA_PATH,in_file), encoding='utf-8-sig')
    docs = df['generated_text'].tolist()
    in_data_files.append(df)
    in_docs.append(docs)
    total_docs.extend(docs)
# Out:
# Loading file :umsun_A_2_sborder.csv ...
# Loading file :umsun_B_sborder.csv ...
# Loading file :umsun_clean_C.csv ...

# %%
# 불용어를 정의한다
user_stop_word = [ "거", "바", "뻥", "중", "눌", ]

# 학습한다.
noun_extractor = LRNounExtractor()
nouns = noun_extractor.train_extract(total_docs)

word_extractor = WordExtractor(
    min_frequency=4, # example
    min_cohesion_forward=0.05,
    min_right_branching_entropy=0.0
)

word_extractor.train(total_docs)
words = word_extractor.extract()

cohesion_score = {word:score.cohesion_forward for word, score in words.items()}

noun_scores = {noun:score.score for noun, score in nouns.items()}
combined_scores = {noun:score + cohesion_score.get(noun, 0)
    for noun, score in noun_scores.items()}
combined_scores.update(
    {subword:cohesion for subword, cohesion in cohesion_score.items()
    if not (subword in combined_scores)}
)

tokenizer = LTokenizer(scores=combined_scores)

class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger
    def __call__(self, text):
        result = list()
        for word in self.tagger.tokenize(text):
            # 명사이고, 길이가 2이상인 단어이고, 불용어 리스트에 없으면 추가하기
            if word not in user_stop_word: #len(word[0]) > 1 and
                result.append(word)
        return result
# Out:
# [Noun Extractor] used default noun predictor; Sejong corpus predictor
# [Noun Extractor] used noun_predictor_sejong
# [Noun Extractor] All 2398 r features was loaded
# [Noun Extractor] scanning was done (L,R) has (10230, 4980) tokens
# [Noun Extractor] building L-R graph was done
# [Noun Extractor] 1534 nouns are extracted
# training was done. used memory 0.754 Gbory 0.700 Gb
# all cohesion probabilities was computed. # words = 17158
# all branching entropies was computed # words = 20725
# all accessor variety was computed # words = 20725

# %%
custom_tokenizer = CustomTokenizer(tokenizer)
vectorizer = CountVectorizer(tokenizer=custom_tokenizer)

# %%
# Pre-calculate embeddings

#embedding_model = SentenceTransformer("sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens")

embedding_model = SentenceTransformer("snunlp/KR-SBERT-V40K-klueNLI-augSTS")
embeddings = embedding_model.encode(total_docs, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/625 [00:00<?, ?it/s]

# %%
# 차원축소
hdbscan_model = HDBSCAN(min_cluster_size=20, metric='euclidean', cluster_selection_method='eom', prediction_data=True)

# %%
# zero-shot
ko_classifier = pipeline(
    task='zero-shot-classification',
    model='MoritzLaurer/DeBERTa-v3-large-mnli-fever-anli-ling-wanli',
    device=0,
    # hypothesis_template='구매하는 이유는 {} 이다.',
)

# %%
CANDIDATE_LABELS = ['첨가물','성분','위험','아기','안심','칼로리','중위험','아이']

# %%
# [0] => A파일 , [1] => B파일 , [2] => C파일

docs = in_docs[2]

# %%
topic_model = BERTopic(
        embedding_model=embedding_model,
        hdbscan_model=hdbscan_model,
        vectorizer_model=vectorizer,
        nr_topics="auto", # 문서를 대표하는 토픽의 갯수
        # top_n_words=4,
        zeroshot_topic_list=CANDIDATE_LABELS,
        zeroshot_min_similarity=.5,
        # representation_model=ko_classifier,
        representation_model=KeyBERTInspired(),
        calculate_probabilities=True
)
	
topics, probs = topic_model.fit_transform(docs)
topic_model.get_topic_info()[:30]
# Out:
#     Topic  Count                     Name  \
# 0       0   1003                      첨가물
# 1       1    624                       성분
# 2       2    135                       아기
# 3       3    125                       안심
# 4       4     38                      중위험
# 5       5     32                      칼로리
# 6       6     22                       아이
# 7       7      4                       위험
# 8       8   3074      -1_먹어요_첨가물_먹었는데_맛있어
# 9       9   1738        0_맛있어_먹어요_맛있_먹어요.
# 10     10    437           1_우유_생우유_분유_두유
# 11     11    158     2_먹었는데_먹었었는데_먹였는데_맛이
# 12     12    105           3_새우_맛있_볶음밥_맛이
# 13     13    104     4_달아요_달아요._달아서_느끼해요.
# 14     14     90         5_치즈_크림치즈_맛있_맛있어
# 15     15     88     6_중위험군_저위험군_먹었는데_중위험
# 16     16     88            7_딸기_상큼_과일_맛있
# 17     17     85      8_요구르트_먹여봤는데_성분_첨가물
# 18     18     83    9_맛나더라고요._맛있어_먹어요._맛있
# 19     19     78          10_성분_함유_분유_조절제
# 20     20     72  11_먹어봐야겠네요._맛있_드셔보시_효능이
# 21     21     71          12_참치_연어_맛있어_맛있
# 22     22     63         13_향뿐만_향료_향부터_향을
# 23     23     57          14_맥주_소주_한잔_소주와
# 24     24     49      15_아침_배불러요._먹음_다이어터
# 25     25     45         16_고구마_맛있어_맛있_상큼
# 26     26     44          17_두부_김치_간장_먹어요
# 27     27     44        18_캐러멜_색소_넣었네요_색감
# 28     28     42     19_맛있어_맛있_먹어야겠어요._쫀득
# 29     29     40        20_주스._주스인_주스_오렌지
#
#                                        Representation  \
# 0       [첨가물, 첨가, 나트륨, 성분, 먹었는데, 우유, 식품, 영양, 먹으면, 맛있]
# 1        [성분, 상큼, 크림, 향이, 생크림, 향료, 첨가물, 맛도, 젤리, 좋네요.]
# 2    [아기, 아기들, 아가, 7개월, 아이, 임신, 먹어요, 먹어요., 먹네요, 있어요.]
# 3        [좋네요., 괜찮, 만족, 좋은, 안심, 다행, 무난, 맘에, 감사, 이네요.]
# 4       [중위험, 저위험, 중위험군, 고위험, 대비, 무난, 안, 가성비, 하나, 들어]
# 5   [칼로리, 다이어트, 섭취, 나트륨, 함량, 맛있어, 다이어터, 감미료, 만해요.,...
# 6   [귀여워요., 귀여운, 아이, 아가, 좋더라고요., 아이들, 부드럽고, 울아가, 너...
# 7    [위험, 중위험군, 저위험, 있어서, 있군요., 회산데, 하하., 아, 있네요, 하나]
# 8       [먹어요, 첨가물, 먹었는데, 맛있어, 맛있, 맛이, 식품, 맛, 맛도, 먹으면]
# 9     [맛있어, 먹어요, 맛있, 먹어요., 맛도, 초콜릿, 맛, 좋네요., 맛이, 같아요]
# 10   [우유, 생우유, 분유, 두유, 서울우유, 유기농, 첨가물, 먹는데, 성분, 먹였는데]
# 11  [먹었는데, 먹었었는데, 먹였는데, 맛이, 먹을래요., 맛있어, 먹길, 맛있, 먹어...
# 11  [이거 사 먹어 보고 싶었는데 안 사 먹길 잘했네요., 이거 자주 먹었는데., 이거...
# 12  [국민 과자 새우깡 첨가물도 없고 좋네요., 새우깡 맛있어요., 새우깡 너무 잘 먹...
# 13  [너무 달지 않아서 좋더라고요 다른 제품은 너무 달아서 느끼한데., 이건 너무 달아...
# 14  [첨가물 없는 치즈라 더 좋아요., 치즈가 들어가서 더 맛있어요., 치즈케이크 맛있...
# 15  [맛있는데 중위험이네요 맛있는 건 왜 다 위험한 건지., 저위험 중위험 위험군들이 ...
# 16  [딸기 달달해서 아이가 잘 먹어서 좋더라고요., 딸기 맛 아이스크림 좋아하는데 진짜...
# 17  [요구르트 보면 요구르트 향이 들어가더라고요 저희 아이는 하루에 요구르트 2개씩 먹...
# 18  [요거 요거 맛 괜찮아요 얇아서 많이 씹을 수 있는 느낌이어서 자주 사 먹고 있어요...
# 19  [안녕하세요 쏘쏘블링님 먼저 엄선으로 인해 불편을 드려 진심으로 사과드립니다 금일 ...
# 20  [처음 본 제품인데 먹어 보고 싶어요., 저도 먹어보고 싶네요., 저도요 한번 먹어...
# 21  [역시 참치는 동원이네요 믿고 먹을 수 있어요., 참치는 동원이죠., 살코기 참치는...
# 22  [향료가 들어가서 아쉽네., 향료가 들어가 있긴 하지만 이 정도의 향료는 대부분 들...
# 23      [맥주 안주로 굿굿., 이건 맥주 안주로 아주 괜찮네요., 맥주 안주로 최고죠.]
# 24  [아침 대용으로 항상 먹고 있어요 간편하고 넘 좋아요., 간편히 아침 대용으로도 좋...
# 25  [진짜 고구마칩 넘 맛있어요., 맛있어요 고구마 말랭이는 다 맛있더라고요., 고구마...
# 26  [두부 부침개나 조림해서 먹어요 두부 김치 해 먹어도 맛있어서 금방 먹어요., 고소...
# 27  [캐러멜 색소 노노노노., 캐러멜 색소는 참 여러 군데 많이 들었네요 스벅의 캐러멜...
# 28                              [맛있어요., 맛있어요., 맛있어요.]
# 29  [발렌시아 오렌지주스 맛나요 무난한 오렌지주스., 오오 오렌지 농축 과즙만 들어있는...

# %%
hierarchical_topics = topic_model.hierarchical_topics(docs)
tree = topic_model.get_topic_tree(hierarchical_topics)
print(tree)

# %%
# Coherence
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

# Preprocess documents for coherence evaluation
documents = pd.DataFrame({"Document": docs, "ID": range(len(docs)), "Topic": topics})
documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ''.join})
cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

# Extract vectorizer and analyzer for BERTopic
vectorizer = topic_model.vectorizer_model
analyzer = vectorizer.build_analyzer()

# Extract features for topic coherence evaluation
words = vectorizer.get_feature_names_out()
tokens = [analyzer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]

# Extract words in each topic if they are non-empty and exist in the dictionary
topic_words = []
#topic_words = [list(zip(*model_2024_B_3.get_topic(topic)))[0] for topic in range(len(set(topics))-1)]
for topic in range(len(set(topics))-topic_model._outliers):
  words = list(zip(*topic_model.get_topic(topic)))[0]
  words = [word for word in words if word in dictionary.token2id]
  topic_words.append(words)
topic_words = [words for words in topic_words if len(words)>0]

# Evaluate Coherence
coherence_model = CoherenceModel(topics=topic_words, texts=tokens, corpus=corpus, dictionary=dictionary, coherence='c_v')
coherence = coherence_model.get_coherence()
print("Coherence Score: ", coherence)
