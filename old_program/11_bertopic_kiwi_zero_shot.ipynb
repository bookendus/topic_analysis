# %%
import pandas as pd
import os

from kiwipiepy import Kiwi

from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer

from hdbscan import HDBSCAN
from sentence_transformers import SentenceTransformer
from transformers import pipeline
from bertopic.representation import KeyBERTInspired

# %%
IN_DATA_PATH = './data/01_out'
OUT_DATA_PATH = './data/02_out'

in_data_files = []
in_docs = []
total_docs = []

# 폴더내 파일리스트를 가져온다.
input_files = os.listdir(IN_DATA_PATH)

# 입력 파일 로딩 RAW_DATA_PATH에 있는 파일을 DataFrame으로 읽어 드린다.
for in_file in input_files:
    print ("Loading file :%s ..."%in_file)
    df = pd.read_csv(os.path.join(IN_DATA_PATH,in_file), encoding='utf-8-sig')
    docs = df['generated_text'].tolist()
    in_data_files.append(df)
    in_docs.append(docs)
    total_docs.extend(docs)
# Out:
# Loading file :umsun_A_2_sborder.csv ...
# Loading file :umsun_B_sborder.csv ...
# Loading file :umsun_clean_C.csv ...

# %%
# 불용어를 정의한다
user_stop_word = [ "거", "바", "뻥", "눌", ]

# 토크나이저에 ***만 추가한다      https://incredible.ai/nlp/2016/12/28/NLP/
extract_pos_list = ["NNG", "NNP", "NNB", "NR", "NP", "VV", "VA","MAG","IC"]

class CustomTokenizer:
    def __init__(self, tagger):
        self.tagger = tagger
    def __call__(self, text):
        result = list()
        for word in self.tagger.tokenize(text):
            # 명사이고, 길이가 2이상인 단어이고, 불용어 리스트에 없으면 추가하기
            if word[1] in extract_pos_list and word[0] not in user_stop_word: #len(word[0]) > 1 and
                result.append(word[0])
        return result

# 커스텀 단어 등록
kiwi = Kiwi()
kiwi.add_user_word("노브랜드","NNP")
kiwi.add_user_word("한살림","NNP")
kiwi.add_user_word("이마트","NNP")
kiwi.add_user_word("피코크","NNP")
kiwi.add_user_word("누네띠네","NNP")
kiwi.add_user_word("동원참치","NNP")
kiwi.add_user_word("떡뻥","NNP")
kiwi.add_user_word("베지밀","NNP")
kiwi.add_user_word("네스카페","NNP")
kiwi.add_user_word("맥스봉","NNP")
kiwi.add_user_word("오뚜기","NNP")
kiwi.add_user_word("오징어집","NNP")
kiwi.add_user_word("오곡쿠키","NNP")

kiwi.add_user_word("10대","NR")
kiwi.add_user_word("20대","NR")
kiwi.add_user_word("30대","NR")
kiwi.add_user_word("40대","NR")
kiwi.add_user_word("50대","NR")
kiwi.add_user_word("베스킨라빈스","NNP")
kiwi.add_user_word("이산화규소","NNP")
kiwi.add_user_word("중위험","NNP")
kiwi.add_user_word("고위험","NNP")
kiwi.add_user_word("저위험","NNP")
kiwi.add_user_word("우리밀","NNP")
kiwi.add_user_word("열일","NNG")
kiwi.add_user_word("유전자변형","NNG")
kiwi.add_user_word("유화증진제","NNG")
kiwi.add_user_word("유화제","NNG")
kiwi.add_user_word("스프레드","NNG")
kiwi.add_user_word("식품첨가물","NNG")
# Out:
# True

# %%
custom_tokenizer = CustomTokenizer(kiwi)
vectorizer = CountVectorizer(tokenizer=custom_tokenizer)

# %%
# Pre-calculate embeddings

#embedding_model = SentenceTransformer("sentence-transformers/xlm-r-100langs-bert-base-nli-stsb-mean-tokens")

embedding_model = SentenceTransformer("snunlp/KR-SBERT-V40K-klueNLI-augSTS")
embeddings = embedding_model.encode(total_docs, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/625 [00:00<?, ?it/s]

# %%
# 차원축소
hdbscan_model = HDBSCAN(min_cluster_size=20, metric='euclidean', cluster_selection_method='eom', prediction_data=True)

# %%
# zero-shot
ko_classifier = pipeline(
    task='zero-shot-classification',
    model='MoritzLaurer/DeBERTa-v3-large-mnli-fever-anli-ling-wanli',
    device=0,
    # hypothesis_template='구매하는 이유는 {} 이다.',
)

# %%
CANDIDATE_LABELS = ['첨가물','성분','위험','아기','안심','칼로리','중위험','아이']

# %%
# [0] => A파일 , [1] => B파일 , [2] => C파일

docs = in_docs[2]

# %%
topic_model = BERTopic(
        embedding_model=embedding_model,
        hdbscan_model=hdbscan_model,
        vectorizer_model=vectorizer,
        nr_topics="auto", # 문서를 대표하는 토픽의 갯수
        # top_n_words=4,
        zeroshot_topic_list=CANDIDATE_LABELS,
        zeroshot_min_similarity=.5,
        # representation_model=ko_classifier,
        representation_model=KeyBERTInspired(),
        calculate_probabilities=True
)
	
topics, probs = topic_model.fit_transform(docs)
topic_model.get_topic_info()[:30]
# Out:
# /home/bookendus/.local/lib/python3.10/site-packages/numba/np/ufunc/parallel.py:371: NumbaWarning: The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)
#     Topic  Count                   Name  \
# 0       0   1003                    첨가물
# 1       1    624                     성분
# 2       2    135                     아기
# 3       3    125                     안심
# 4       4     38                    중위험
# 5       5     32                    칼로리
# 6       6     22                     아이
# 7       7      4                     위험
# 8       8   3151         -1_젤리_단맛_맛있_간식
# 9       9   1133           0_맛있_간식_맛_식품
# 10     10    392         1_우유_분유_두유_첨가물
# 11     11    226          2_과자_맛있_간식_식품
# 12     12    200  3_초코칩쿠키_초코바_초코크로와_초코칩
# 13     13    128       4_소시지_육즙_맛있_쫄깃쫄깃
# 14     14    106          5_너무_밋밋하_달_별로
# 15     15    103        6_새우깡_새우_매운맛_맛있
# 16     16    100       7_라면_진라면_컵라면_스낵면
# 17     17     91        8_먹_농심_땡뚜기_노브랜드
# 18     18     89    9_치즈_치즈볼_치즈케이크_치즈스틱
# 19     19     88    10_딸기우유_딸기_상큼하_블루베리
# 20     20     83      11_요구르트_단맛_첨가물_신맛
# 21     21     81          12_맛나_꿀맛_맛있_맛
# 22     22     78        13_맛있_위험군_먹_고위험
# 23     23     77         14_구입_구매_매장_판매
# 24     24     72    15_참치_참치김치찌개_연어_오징어
# 25     25     72       16_떡볶이_라볶이_국물_김밥
# 26     26     64       17_향료_감미료_조미료_향미
# 27     27     62        18_맥주_소주_한잔_술안주
# 28     28     45    19_아침밥_아침_다이어터_다이어트
# 29     29     45   20_고구마_고구마츄네요_우리밀_맛있
#
#                                        Representation  \
# 0          [첨가물, 첨가, 맛있, 설탕, 영양, 우유, 성분, 유기농, 나트륨, 맛]
# 1         [성분, 크림, 감미료, 첨가물, 젤리, 천연, 함유, 향료, 초콜릿, 맛있]
# 2         [아기, 아가, 애기, 아이, 임신, 맛있, 우유, 유기농, 기쁘, 요구르트]
# 3           [괜찮, 안심, 만족, 무난하, 꿀맛, 최고, 다행, 인정, 건강, 감사]
# 4         [중위험, 저위험, 고위험, 대비, 안, 가성비, 하나, 아커, 필요, 대박]
# 5   [칼로리, 섭취, 나트륨, 다이어트, 감미료, 함량, 다이어터, 지방산, 요구르트,...
# 6             [아이, 아가, 아기, 너무, 맛있, 울아, 어머, 울, 착하, 성분]
# 7             [위험, 저위험, 중위험, 하하, 아, 하나, 분, 조금, 있, 유명]
# 8             [젤리, 단맛, 맛있, 간식, 맛나, 첨가물, 식감, 맛, 식품, 먹]
# 9           [맛있, 간식, 맛, 식품, 첨가물, 먹, 초콜릿, 성분, 달달하, 식감]
# 10         [우유, 분유, 두유, 첨가물, 유기농, 식품, 성분, 먹이, 아기, 맛있]
# 11           [과자, 맛있, 간식, 식품, 성분, 맛, 첨가물, 아가, 엄마, 향료]
# 12  [초코칩쿠키, 초코바, 초코크로와, 초코칩, 초코, 초코파이, 초콜릿, 맛있, 아이...
# 13      [소시지, 육즙, 맛있, 쫄깃쫄깃, 비빔면, 먹, 양념, 둥지냉면, 오뎅, 짬뽕]
# 14          [너무, 밋밋하, 달, 별로, 동글, 좀, 걸쭉하, 덜, 무난하, 느끼하]
# 15          [새우깡, 새우, 매운맛, 맛있, 볶음밥, 맛, 튀김, 농심, 먹, 과자]
# 16       [라면, 진라면, 컵라면, 스낵면, 국물, 밥, 오뚜기, 갓뚜기, 입맛, 끓이]
# 17       [먹, 농심, 땡뚜기, 노브랜드, 놔두, 일부러, 취소, 먹이, 아이쿠, 아까]
# 18  [치즈, 치즈볼, 치즈케이크, 치즈스틱, 맛있, 크림치즈, 맛나, 맛도, 맛, 렌치소스]
# 19     [딸기우유, 딸기, 상큼하, 블루베리, 과일, 맛있, 주스, 감귤, 요구르트, 맛]
# 20   [요구르트, 단맛, 첨가물, 신맛, 맛, 마시, 천연, 유산균, 아기, 아이스브레이커]
# 21             [맛나, 꿀맛, 맛있, 맛, 캡슐, 요거, 먹, 첨가물, 꿀, 끓이]
# 22   [맛있, 위험군, 먹, 고위험, 중위험, 카페인, 저위험, 위험, 있었네인산큽, 치킨]
# 23            [구입, 구매, 매장, 판매, 마트, 처음, 제품, 첨, 우와, 맛보]
# 24     [참치, 참치김치찌개, 연어, 오징어, 국물, 통조림, 볶음밥, 맛있, 찌개, 밥]
# 25      [떡볶이, 라볶이, 국물, 김밥, 매운맛, 맛있, 분식집, 쫄깃하, 맛나, 수프]
# 26         [향료, 감미료, 조미료, 향미, 향, 맛, 착색료, 천연, 카레, 유기농]
# 27          [맥주, 소주, 한잔, 술안주, 술, 막걸리, 보리차, 잔, 마시, 홍차]
# 28    [아침밥, 아침, 다이어터, 다이어트, 수프, 점심, 식사, 건강, 샐러드, 컵누들]
# 29  [고구마, 고구마츄네요, 우리밀, 맛있, 상큼하, 달달하, 식감, 맛, 군고구마, 단맛]
#
#                                   Representative_Docs
# 0   [첨가물이 없어서 좋아요., 첨가물도 없고 고소해서 좋아해요., 첨가물이 없어서 좋...
# 1          [성분이 좋네요., 맛도 좋고 한데 성분 아쉽네요., 맛도 성분도 좋아요.]
# 2              [아기한테 먹이면 좋겠어요., 아기가 좋아해요., 아기가 좋아해요.]
# 3                          [괜찮아 괜찮아., 괜찮아요., 괜찮은 제품.]
# 4                            [중위험., 중위험., 중위험이 아쉽네요.]
# 5   [칼로리가 낮아서 좋다며 먹었는데 감미료가., 칼로리가 너무 높다고 생각이 듭니다....
# 6      [제가 좋아해요 아이는 주지 말아야겠어요., 아이가 좋아해요., 아이가 좋아해요.]
# 7   [위험분이 있군요., 위험분이 하나 있네요 하하., 거버 유명한 회산데 중위험군 조...
# 8   [밥하기 싫을 때 간편하게 먹을 수 있어서 좋은데 첨가물도 없다니 더 자주 먹을 것...
# 9   [아이들과 먹기 좋아서., 식품 첨가물에 들어가는 산도 조절제에는 안전한 성분도 있...
# 10  [저희 아기가 멸균 우유 먹고 있는데 이제 생우유로 바꾸려고 하는데 안 그래도 검색...
# 11                  [좋아하는 과자요., 과자는 맛있어., 잘 먹는 과자예요.]
# 12  [역시 초코쿠키는., 초코 쿠키 씹히는 맛도 맛있어요., 초코쿠키는 안 먹어 봤는데...
# 13  [다이어트할 때 좋은 것 같아요 소시지 먹는데 소시지가 아니야., 닭 가슴살 소시지...
# 14             [이건 너무 달아요., 달지 않아서 좋아해요., 저는 너무 달아요.]
# 15                [역시 새우깡., 새우깡 너무 잘 먹는데., 새우깡 맛있어요.]
# 16  [우리 밀라면이라고는 해도 역시 라면은 라면이네요., 저는 좋아하는 라면이에요., ...
# 17  [이건 사주지 않는 거로., 이건 안 먹어 봤는데 안 먹길 잘했네요., 이거 사 먹...
# 18  [치즈가 들어가서 더 맛있어요., 첨가물 없는 치즈라 더 좋아요., 첨가물 없는 치...
# 19  [딸기 맛은 별로 안 나요., 딸기 맛 아이스크림 좋아하는데 진짜 딸기 들어간 것 ...
# 20  [그래도 요구르트는 달아요., 다른 요구르트에서 느낄 수 없는 진짜 요구르트., 요...
# 21              [요거 생각보다 맛나더라고요., 요거 맛난데., 요거 맛나나요?.]
# 22  [저위험이 4개라니 궁금하지만 안 먹을래요., 저위험이 7개나 있네요 안 먹어야겠어...
# 23  [이 제품은 처음 보네요 어디서 구매가 가능한 건가요?., 처음 봐요 어디서 파는 ...
# 24  [참치는 동원 첨가물도 없고 담백해서 이것만 사 먹어요., 역시 참치는 동원이네요 ...
# 25  [쌀떡볶이를 밀떡볶이보다 좋아하는지라 맛있게 먹었어요 향미 증진제가 좀 빠져도 괜찮...
# 26  [이런 맛살들에도 다 향료가 들어간다니., 향료가 들어가 있긴 하지만 이 정도의 향...
# 27  [아이들보다 내가 더 좋아하는 맥주 안주로도 딱이에요., 맥주 안주로 이만한 게 없...
# 28      [아침마다 먹는데., 간편히 아침 대용으로도 좋아요., 아침 대용으로 딱입니다.]
# 29  [자색 고구마 맛은 처음인데 더 맛있을 것 같아 보여요., 고구마라 무난 무난한 맛...

# %%
hierarchical_topics = topic_model.hierarchical_topics(docs)
tree = topic_model.get_topic_tree(hierarchical_topics)
print(tree)

# %%
# Coherence
import gensim.corpora as corpora
from gensim.models.coherencemodel import CoherenceModel

# Preprocess documents for coherence evaluation
documents = pd.DataFrame({"Document": docs, "ID": range(len(docs)), "Topic": topics})
documents_per_topic = documents.groupby(['Topic'], as_index=False).agg({'Document': ''.join})
cleaned_docs = topic_model._preprocess_text(documents_per_topic.Document.values)

# Extract vectorizer and analyzer for BERTopic
vectorizer = topic_model.vectorizer_model
analyzer = vectorizer.build_analyzer()

# Extract features for topic coherence evaluation
words = vectorizer.get_feature_names_out()
tokens = [analyzer(doc) for doc in cleaned_docs]
dictionary = corpora.Dictionary(tokens)
corpus = [dictionary.doc2bow(token) for token in tokens]

# Extract words in each topic if they are non-empty and exist in the dictionary
topic_words = []
#topic_words = [list(zip(*model_2024_B_3.get_topic(topic)))[0] for topic in range(len(set(topics))-1)]
for topic in range(len(set(topics))-topic_model._outliers):
  words = list(zip(*topic_model.get_topic(topic)))[0]
  words = [word for word in words if word in dictionary.token2id]
  topic_words.append(words)
topic_words = [words for words in topic_words if len(words)>0]

# Evaluate Coherence
coherence_model = CoherenceModel(topics=topic_words, texts=tokens, corpus=corpus, dictionary=dictionary, coherence='c_v')
coherence = coherence_model.get_coherence()
print("Coherence Score: ", coherence)
